# %%
# %run main.py
# Out:
# 2020-01-01 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# first_day->  2012-11-01 00:00:00
# last_day->  2018-12-31 00:00:00
# Lombardia; number of dataframes created ->  94

# %%
metadata_df
# Out:
#        code  latitudine  longitudine  altitudineslm  \
# 0    lmb002   45.930000     9.470000            750
# 1    lmb005   45.170000     9.630000             60
# 2    lmb006   45.609504     9.893703            183
# 3    lmb010   45.660679     9.131296            225
# 4    lmb021   45.653116     9.198995            224
# ..      ...         ...          ...            ...
# 97   pmn101   45.657338     8.400893            370
# 98   pmn105   45.741652     8.410850            452
# 99   pmn109   45.397410     8.719186            129
# 100  pmn125   45.763841     8.554144            365
# 101  pmn147   45.470331     8.694344            150
#
#                                         strumentazione    regione  \
# 0             Davis Vantage Pro 2, pluviometro manuale  Lombardia
# 1                       Oregon Scientific Bar928 Giove  Lombardia
# 2                                  Davis Vantage Pro 2  Lombardia
# 3    Oregon Scientific WMR918, termometro a mercuri...  Lombardia
# ...

# %%
station_df
# Out:
#      datetime  t_min  t_med  t_max
# 0  2018-12-10    2.0    7.3   12.0
# 1  2018-12-11   -1.3    3.5   10.3
# 2  2018-12-12   -4.0   -0.7    6.1
# 3  2018-12-13   -2.6   -0.2    5.4
# 4  2018-12-14   -5.1   -2.0    4.1
# 5  2018-12-15   -6.2   -3.0    3.7
# 6  2018-12-16   -3.5   -1.0    0.9
# 7  2018-12-17   -2.3   -0.2    5.5
# 8  2018-12-18   -3.5   -0.2    6.7
# 9  2018-12-19   -2.4   -0.6    1.2
# 10 2018-12-20   -0.4    0.6    1.9
# 11 2018-12-21   -2.6    0.6    5.4
# 12 2018-12-22   -0.4    2.2    7.9
# 13 2018-12-23    0.5    3.0    7.9
# 14 2018-12-24    1.0    6.5   15.6
# 15 2018-12-25   -1.4    2.3    9.4
# 16 2018-12-26   -2.2    1.0    7.8
# 17 2018-12-27   -2.5    1.3    7.7
# 18 2018-12-28   -0.2    3.1    8.3
# 19 2018-12-29    0.6    3.7   10.2
# 20 2018-12-30   -0.2    7.5   14.4
# 21 2018-12-31    0.3    3.9   10.7
